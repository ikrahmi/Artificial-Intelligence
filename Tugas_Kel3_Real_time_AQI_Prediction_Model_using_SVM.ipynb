# %% [markdown]
# <a href="https://colab.research.google.com/github/ikrahmi/Artificial-Intelligence/blob/main/Tugas_Kel3_Real_time_AQI_Prediction_Model_using_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Machine learning model for real-time prediction AQI in Jakarta**

# %% [markdown]
# **1. Import Packages**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVC

# %% [markdown]
# **2. Import Dataset**

# %% [markdown]
# Dataset berisi mengenai Indeks Standar Pencemar Udara (ISPU) DKI Jakarta Tahun 2010-2021.

# %%
data = pd.read_csv('/content/drive/MyDrive/Semester Satu/DataScience/AQI_jakarta_2010_2021.csv')
data.head()
# Out:
#     tanggal             stasiun  pm10  so2    co    o3   no2  max critical  \
# 0  1/1/2010  DKI1 (Bunderan HI)  60.0  4.0  73.0  27.0  14.0   73       CO
# 1  1/2/2010  DKI1 (Bunderan HI)  32.0  2.0  16.0  33.0   9.0   33       O3
# 2  1/3/2010  DKI1 (Bunderan HI)  27.0  2.0  19.0  20.0   9.0   27     PM10
# 3  1/4/2010  DKI1 (Bunderan HI)  22.0  2.0  16.0  15.0   6.0   22     PM10
# 4  1/5/2010  DKI1 (Bunderan HI)  25.0  2.0  17.0  15.0   8.0   25     PM10
#
#   categori
# 0   SEDANG
# 1     BAIK
# 2     BAIK
# 3     BAIK
# 4     BAIK

# %%
data.shape          # cek dimensi data
# Out:
# (4272, 10)

# %% [markdown]
# **3. Exploratory Data Analysisi (EDA)**

# %% [markdown]
# *3.1. Delete feature yang tidak berpengaruh secara langsung terhadap target, yaitu: tanggal, stasiun, max dan critical*

# %%
data.drop(columns=['tanggal','stasiun', 'max','critical'], inplace=True)

# %% [markdown]
# *3.2. Cek metadata*

# %%
data.dtypes
# Out:
# pm10        float64
# so2         float64
# co          float64
# o3          float64
# no2         float64
# categori     object
# dtype: object

# %%
# cek jumlah kelas variabel target
data.categori.unique()
# Out:
# array(['SEDANG', 'BAIK', 'TIDAK SEHAT'], dtype=object)

# %% [markdown]
# 3.3. Cek apakah data imbalance

# %%
data.categori.value_counts()
# Out:
# SEDANG         3064
# BAIK           1054
# TIDAK SEHAT     154
# Name: categori, dtype: int64

# %% [markdown]
# 3.4. Cek Missing value

# %%
data.isna().sum()
# Out:
# pm10        102
# so2          65
# co           40
# o3           93
# no2          83
# categori      0
# dtype: int64

# %% [markdown]
# 3.5. Cek data duplikat dan drop jika ada

# %%
data.duplicated().sum()         # cek data duplikat
# Out:
# 3

# %%
data = data.drop_duplicates()   # drop data duplikat

# %% [markdown]
# **4. Splitting Dataset**

# %% [markdown]
# Splitting dataset menjadi feature (X) dan target (y), kemudian split lagi menjadi data training dan data test

# %% [markdown]
# *Kasus regresi gunakan shuffle splitting, kasus klasifikasi gunakan stratified shuffle splitting. Nilai parameter shuffling (random_state) yang umum digunakan adalah 0 atau 1 atau 42.*

# %%
# split data menjadi X dan y
X = data.drop(columns='categori')
y = data.categori

# split X dan y menjadi train dan test
# stratify = 9 maksudnya di selang-selang berdasarkan kolom y (target). Random_state artinya proses shuffling dikontrol agar reproduceable
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, stratify=y,  random_state=42)

# tampilkan shape
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3415, 5), (854, 5), (3415,), (854,))

# %% [markdown]
# **5. Preprocessor dan Pipeline**

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %% [markdown]
# 5.1. Menyiapkan pipeline untuk data numerik dan kategorikal

# %%
# pipeline untuk data numerik: melewati proses impute dan scaling

numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', MinMaxScaler())
])

# %%
'''
# pipeline untuk data kategorikal: melewati proses impute dan encoding

kategorikal_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoding', OneHotEncoder())
])
'''
# Out:
# "\n# pipeline untuk data kategorikal: melewati proses impute dan encoding\n\nkategorikal_pipeline = Pipeline([\n    ('imputer', SimpleImputer(strategy='most_frequent')),\n    ('encoding', OneHotEncoder())\n])\n"

# %% [markdown]
# 5.2. Menyiapkan sebuah pipeline-preprocessor yang akan berisi pipeline numerik dan kategorik

# %%
pipeline_preprocessor = ColumnTransformer([
    ('numeric', numerical_pipeline,['pm10','so2','co','o3','no2'])       # kolom yang masuk ke pipeline numerik
])

# note: karena di dataset tidak ada feature yang berbentuk kategorik maka pipeline kategorik tidak diperlukan

# %% [markdown]
# 5.3. Menyiapkan sebuah pipeline model yang akan berisi pipeline preprocessor dan pipilne algoritma yang akan digunakan

# %%
pipeline_model = Pipeline([
    ('preprocessor', pipeline_preprocessor),
    ('algoritma', SVC())
])

# %% [markdown]
# **6. SVM parameter tuning dengan GridSearchCV dan model training**

# %%
# cek parameter apa saja yang bisa di tuning pada model

pipeline_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(transformers=[('numeric',
#                                     Pipeline(steps=[('imputer', SimpleImputer()),
#                                                     ('scaler', MinMaxScaler())]),
#                                     ['pm10', 'so2', 'co', 'o3', 'no2'])])),
#   ('algoritma', SVC())],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(transformers=[('numeric',
#                                   Pipeline(steps=[('imputer', SimpleImputer()),
#                                                   ('scaler', MinMaxScaler())]),
#                                   ['pm10', 'so2', 'co', 'o3', 'no2'])]),
#  'algoritma': SVC(),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('numeric',
#    Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', MinMaxScaler())]),
#    ['pm10', 'so2', 'co', 'o3', 'no2'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__numeric': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', MinMaxScaler())]),
#  'preprocessor__numeric__memory': None,
#  'preprocessor__numeric__steps': [('imputer', SimpleImputer()),
#   ('scaler', MinMaxScaler())],
#  'preprocessor__numeric__verbose': False,
#  'preprocessor__numeric__imputer': SimpleImputer(),
#  'preprocessor__numeric__scaler': MinMaxScaler(),
#  'preprocessor__numeric__imputer__add_indicator': False,
#  'preprocessor__numeric__imputer__copy': True,
#  'preprocessor__numeric__imputer__fill_value': None,
#  'preprocessor__numeric__imputer__keep_empty_features': False,
#  'preprocessor__numeric__imputer__missing_values': nan,
#  'preprocessor__numeric__imputer__strategy': 'mean',
#  'preprocessor__numeric__imputer__verbose': 'deprecated',
#  'preprocessor__numeric__scaler__clip': False,
#  'preprocessor__numeric__scaler__copy': True,
#  'preprocessor__numeric__scaler__feature_range': (0, 1),
#  'algoritma__C': 1.0,
#  'algoritma__break_ties': False,
#  'algoritma__cache_size': 200,
#  'algoritma__class_weight': None,
#  'algoritma__coef0': 0.0,
#  'algoritma__decision_function_shape': 'ovr',
#  'algoritma__degree': 3,
#  'algoritma__gamma': 'scale',
#  'algoritma__kernel': 'rbf',
#  'algoritma__max_iter': -1,
#  'algoritma__probability': False,
#  'algoritma__random_state': None,
#  'algoritma__shrinking': True,
#  'algoritma__tol': 0.001,
#  'algoritma__verbose': False}

# %%
parameter = {
    'algoritma__gamma': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
    'algoritma__C': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]
    }

model = GridSearchCV(pipeline_model, parameter,cv=3, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

# note: hasil model.fit --> 49 candidat (7 variasi gamma x 7 variasi C = 49)
#                       --> 147 fits ( 49 candididat x 3 cv = 147)
# Out:
# Fitting 3 folds for each of 49 candidates, totalling 147 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['pm10',
#                                                                           'so2',
#                                                                           'co',
#                                                                           'o3',
#                                                                           'no2'])])),
#                                        ('algoritma', SVC())]),
#              n_jobs=-1,
#              param_grid={'algoritma__C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                           1000.0],
#                          'algoritma__gamma': [0.001, 0.01, 0.1, 1.0, 10.0,
#                                               100.0, 1000.0]},
#              verbose=1)

# %% [markdown]
# **7. Model Evaluation**

# %%
model.best_params_      # menampilkan kombinasi parameter terbaik berdasarkan gridsearchCV
# Out:
# {'algoritma__C': 1000.0, 'algoritma__gamma': 1.0}

# %%
# tampilkan score training,validation & testing

print(f'Training score: {model.score(X_train,y_train)}')
print(f'Validation score: {model.best_score_}')
print(f'Testing sore: {model.score(X_test, y_test)}')
# Out:
# Training score: 0.9628111273792094
# Validation score: 0.9540265178809766
# Testing sore: 0.949648711943794

# %% [markdown]
# *Laporan lengkap hasil gridsearchCV berdasarkan rank test score*

# %%
gs_report = pd.DataFrame(model.cv_results_).sort_values("rank_test_score")
gs_report
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 45       0.335465      0.014763         0.080524        0.019518
# 32       0.139070      0.026193         0.072481        0.023714
# 39       0.115598      0.003624         0.044534        0.001652
# 38       0.108619      0.004890         0.054410        0.000991
# 46       0.508070      0.054336         0.068749        0.020022
# 25       0.197076      0.011404         0.148206        0.003090
# 33       0.493691      0.140609         0.261052        0.072221
# 26       0.618342      0.027681         0.299987        0.013940
# 31       0.161493      0.070066         0.102882        0.029615
# 44       0.216797      0.031513         0.118834        0.022533
# 40       0.281605      0.004495         0.135329        0.002539
# 47       0.562967      0.078766         0.226487        0.053782
# 37       0.124986      0.002150         0.084780        0.009014
# 18       0.124997      0.002131         0.100341        0.001841
# 24       0.258686      0.009002         0.192286        0.002094
# 43       0.195589      0.015462         0.133235        0.045498
# 30       0.197286      0.043299         0.156607        0.040015
# 36       0.128113      0.004836         0.097933        0.002177
# 42       0.125944      0.005744         0.096513        0.002574
# 19       0.465362      0.067449         0.320788        0.039712
# 17       0.163636      0.001977         0.143410        0.014586
# 11       0.200212      0.003045         0.159591        0.001091
# 23       0.365947      0.011589         0.281047        0.010105
# 35       0.231845      0.061151         0.163955        0.031753
# 29       0.269904      0.074204         0.270505        0.016764
# 41       0.726358      0.017105         0.291384        0.005660
# 34       1.264851      0.084681         0.416530        0.100807
# 48       1.275355      0.232546         0.456189        0.104378
# 27       1.419643      0.061787         0.584105        0.010291
# 28       0.409823      0.021112         0.336331        0.011124
# 1        0.326669      0.041252         0.280740        0.058063
# 2        0.291674      0.019622         0.245229        0.063942
# 3        0.208912      0.001354         0.168759        0.001845
# 4        0.214307      0.000806         0.161178        0.001029
# 5        0.225375      0.007644         0.160045        0.002186
# 6        0.230983      0.010695         0.182815        0.009671
# 7        0.197206      0.003007         0.164041        0.001529
# 8        0.197393      0.002054         0.172505        0.009205
# 9        0.206217      0.001433         0.163306        0.000790
# 12       0.290998      0.011372         0.178917        0.004424
# 13       0.566535      0.006034         0.298533        0.011948
# 14       0.208993      0.008642         0.165546        0.004075
# 15       0.212136      0.005068         0.170956        0.013006
# 16       0.205479      0.003618         0.166963        0.000626
# 20       1.277425      0.096769         0.594089        0.051132
# 21       0.375785      0.045834         0.339205        0.029265
# 22       0.416014      0.037449         0.327113        0.015990
# 10       0.203796      0.002797         0.170718        0.008955
# 0        0.372846      0.074426         0.339784        0.002844
#
#    param_algoritma__C param_algoritma__gamma  \
# 45             1000.0                    1.0
# 32               10.0                   10.0
# 39              100.0                   10.0
# 38              100.0                    1.0
# 46             1000.0                   10.0
# 25                1.0                   10.0
# 33               10.0                  100.0
# 26                1.0                  100.0
# 31               10.0                    1.0
# 44             1000.0                    0.1
# 40              100.0                  100.0
# 47             1000.0                  100.0
# 37              100.0                    0.1
# 18                0.1                   10.0
# 24                1.0                    1.0
# 43             1000.0                   0.01
# 30               10.0                    0.1
# 36              100.0                   0.01
# 42             1000.0                  0.001
# 19                0.1                  100.0
# 17                0.1                    1.0
# 11               0.01                   10.0
# 23                1.0                    0.1
# 35              100.0                  0.001
# 29               10.0                   0.01
# 41              100.0                 1000.0
# 34               10.0                 1000.0
# 48             1000.0                 1000.0
# 27                1.0                 1000.0
# 28               10.0                  0.001
# 1               0.001                   0.01
# 2               0.001                    0.1
# 3               0.001                    1.0
# 4               0.001                   10.0
# 5               0.001                  100.0
# 6               0.001                 1000.0
# 7                0.01                  0.001
# 8                0.01                   0.01
# 9                0.01                    0.1
# 12               0.01                  100.0
# 13               0.01                 1000.0
# 14                0.1                  0.001
# 15                0.1                   0.01
# 16                0.1                    0.1
# 20                0.1                 1000.0
# 21                1.0                  0.001
# 22                1.0                   0.01
# 10               0.01                    1.0
# 0               0.001                  0.001
#
#                                                params  split0_test_score  \
# 45  {'algoritma__C': 1000.0, 'algoritma__gamma': 1.0}           0.953468
# 32   {'algoritma__C': 10.0, 'algoritma__gamma': 10.0}           0.955224
# 39  {'algoritma__C': 100.0, 'algoritma__gamma': 10.0}           0.956980
# 38   {'algoritma__C': 100.0, 'algoritma__gamma': 1.0}           0.951712
# 46  {'algoritma__C': 1000.0, 'algoritma__gamma': 1...           0.941176
# 25    {'algoritma__C': 1.0, 'algoritma__gamma': 10.0}           0.947322
# 33  {'algoritma__C': 10.0, 'algoritma__gamma': 100.0}           0.934153
# 26   {'algoritma__C': 1.0, 'algoritma__gamma': 100.0}           0.933275
# 31    {'algoritma__C': 10.0, 'algoritma__gamma': 1.0}           0.937665
# 44  {'algoritma__C': 1000.0, 'algoritma__gamma': 0.1}           0.936787
# 40  {'algoritma__C': 100.0, 'algoritma__gamma': 10...           0.929763
# 47  {'algoritma__C': 1000.0, 'algoritma__gamma': 1...           0.919227
# 37   {'algoritma__C': 100.0, 'algoritma__gamma': 0.1}           0.915716
# 18    {'algoritma__C': 0.1, 'algoritma__gamma': 10.0}           0.913960
# 24     {'algoritma__C': 1.0, 'algoritma__gamma': 1.0}           0.911326
# 43  {'algoritma__C': 1000.0, 'algoritma__gamma': 0...           0.898156
# 30    {'algoritma__C': 10.0, 'algoritma__gamma': 0.1}           0.892011
# 36  {'algoritma__C': 100.0, 'algoritma__gamma': 0.01}           0.889377
# 42  {'algoritma__C': 1000.0, 'algoritma__gamma': 0...           0.889377
# 19   {'algoritma__C': 0.1, 'algoritma__gamma': 100.0}           0.859526
# 17     {'algoritma__C': 0.1, 'algoritma__gamma': 1.0}           0.866550
# 11   {'algoritma__C': 0.01, 'algoritma__gamma': 10.0}           0.859526
# 23     {'algoritma__C': 1.0, 'algoritma__gamma': 0.1}           0.859526
# 35  {'algoritma__C': 100.0, 'algoritma__gamma': 0....           0.858648
# 29   {'algoritma__C': 10.0, 'algoritma__gamma': 0.01}           0.857770
# 41  {'algoritma__C': 100.0, 'algoritma__gamma': 10...           0.778753
# 34  {'algoritma__C': 10.0, 'algoritma__gamma': 100...           0.778753
# 48  {'algoritma__C': 1000.0, 'algoritma__gamma': 1...           0.778753
# 27  {'algoritma__C': 1.0, 'algoritma__gamma': 1000.0}           0.752414
# 28  {'algoritma__C': 10.0, 'algoritma__gamma': 0.001}           0.717296
# 1   {'algoritma__C': 0.001, 'algoritma__gamma': 0.01}           0.717296
# 2    {'algoritma__C': 0.001, 'algoritma__gamma': 0.1}           0.717296
# 3    {'algoritma__C': 0.001, 'algoritma__gamma': 1.0}           0.717296
# 4   {'algoritma__C': 0.001, 'algoritma__gamma': 10.0}           0.717296
# 5   {'algoritma__C': 0.001, 'algoritma__gamma': 10...           0.717296
# 6   {'algoritma__C': 0.001, 'algoritma__gamma': 10...           0.717296
# 7   {'algoritma__C': 0.01, 'algoritma__gamma': 0.001}           0.717296
# 8    {'algoritma__C': 0.01, 'algoritma__gamma': 0.01}           0.717296
# 9     {'algoritma__C': 0.01, 'algoritma__gamma': 0.1}           0.717296
# 12  {'algoritma__C': 0.01, 'algoritma__gamma': 100.0}           0.717296
# 13  {'algoritma__C': 0.01, 'algoritma__gamma': 100...           0.717296
# 14   {'algoritma__C': 0.1, 'algoritma__gamma': 0.001}           0.717296
# 15    {'algoritma__C': 0.1, 'algoritma__gamma': 0.01}           0.717296
# 16     {'algoritma__C': 0.1, 'algoritma__gamma': 0.1}           0.717296
# 20  {'algoritma__C': 0.1, 'algoritma__gamma': 1000.0}           0.717296
# 21   {'algoritma__C': 1.0, 'algoritma__gamma': 0.001}           0.717296
# 22    {'algoritma__C': 1.0, 'algoritma__gamma': 0.01}           0.717296
# 10    {'algoritma__C': 0.01, 'algoritma__gamma': 1.0}           0.717296
# 0   {'algoritma__C': 0.001, 'algoritma__gamma': 0....           0.717296
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 45           0.954306           0.954306         0.954027        0.000395
# 32           0.956063           0.949912         0.953733        0.002723
# 39           0.948155           0.944640         0.949925        0.005191
# 38           0.943761           0.950791         0.948755        0.003551
# 46           0.950791           0.945518         0.945829        0.003931
# 25           0.936731           0.942004         0.942019        0.004324
# 33           0.943761           0.937610         0.938508        0.003974
# 26           0.941125           0.929701         0.934700        0.004771
# 31           0.923550           0.941125         0.934113        0.007602
# 44           0.923550           0.941125         0.933821        0.007475
# 40           0.931459           0.936731         0.932651        0.002967
# 47           0.920035           0.936731         0.925331        0.008068
# 37           0.903339           0.925308         0.914787        0.008993
# 18           0.898067           0.920914         0.910980        0.009562
# 24           0.894552           0.920035         0.908638        0.010576
# 43           0.891037           0.913005         0.900733        0.009152
# 30           0.882250           0.904218         0.892826        0.008987
# 36           0.879613           0.901582         0.890191        0.008987
# 42           0.879613           0.900703         0.889898        0.008618
# 19           0.863796           0.875220         0.866181        0.006625
# 17           0.851494           0.872583         0.863542        0.008869
# 11           0.855009           0.864675         0.859737        0.003949
# 23           0.849736           0.868190         0.859151        0.007538
# 35           0.848858           0.866432         0.857979        0.007190
# 29           0.848858           0.866432         0.857687        0.007175
# 41           0.784710           0.782953         0.782139        0.002499
# 34           0.784710           0.782953         0.782139        0.002499
# 48           0.784710           0.782953         0.782139        0.002499
# 27           0.775923           0.757469         0.761935        0.010103
# 28           0.717926           0.717047         0.717423        0.000370
# 1            0.717926           0.717047         0.717423        0.000370
# 2            0.717926           0.717047         0.717423        0.000370
# 3            0.717926           0.717047         0.717423        0.000370
# 4            0.717926           0.717047         0.717423        0.000370
# 5            0.717926           0.717047         0.717423        0.000370
# 6            0.717926           0.717047         0.717423        0.000370
# 7            0.717926           0.717047         0.717423        0.000370
# 8            0.717926           0.717047         0.717423        0.000370
# 9            0.717926           0.717047         0.717423        0.000370
# 12           0.717926           0.717047         0.717423        0.000370
# 13           0.717926           0.717047         0.717423        0.000370
# 14           0.717926           0.717047         0.717423        0.000370
# 15           0.717926           0.717047         0.717423        0.000370
# 16           0.717926           0.717047         0.717423        0.000370
# 20           0.717926           0.717047         0.717423        0.000370
# 21           0.717926           0.717047         0.717423        0.000370
# 22           0.717926           0.717047         0.717423        0.000370
# 10           0.717926           0.717047         0.717423        0.000370
# 0            0.717926           0.717047         0.717423        0.000370
#
#     rank_test_score
# 45                1
# 32                2
# 39                3
# 38                4
# 46                5
# 25                6
# 33                7
# 26                8
# 31                9
# 44               10
# 40               11
# 47               12
# 37               13
# 18               14
# 24               15
# 43               16
# 30               17
# 36               18
# 42               19
# 19               20
# 17               21
# 11               22
# 23               23
# 35               24
# 29               25
# 41               26
# 34               26
# 48               26
# 27               29
# 28               30
# 1                30
# 2                30
# 3                30
# 4                30
# 5                30
# 6                30
# 7                30
# 8                30
# 9                30
# 12               30
# 13               30
# 14               30
# 15               30
# 16               30
# 20               30
# 21               30
# 22               30
# 10               30
# 0                30

# %% [markdown]
# **8. Menggunakan model untuk melakukan prediksi terhadap data baru**

# %% [markdown]
# Data baru yang akan diprediksi, format (struktur data) nya harus sama dengan struktur data yang digunakan untuk mentraining model. Dalam case ini adalah pandas dataframe

# %%
# 9 data baru yang akan diprediksi

data_pred=pd.read_csv('/content/drive/MyDrive/Semester Satu/DataScience/new_data.csv')
data_pred
# Out:
#    pm10  so2  co  o3  no2
# 0    38   29   6  31   13
# 1    27   27   7  47    7
# 2    44   25   7  40   13
# 3    30   24   4  32    7
# 4    38   24   6  31    9
# 5    41   23  13  46   13
# 6    35   22   6  39   10
# 7    37   26  16  17   10
# 8    47   16  27  22   12

# %%
# Lakukan prediksi

hasil_prediksi= model.predict(data_pred)
hasil_prediksi
# Out:
# array(['SEDANG', 'BAIK', 'SEDANG', 'BAIK', 'BAIK', 'BAIK', 'BAIK', 'BAIK',
#        'BAIK'], dtype=object)

# %%
# Masukkan hasil prediksi dalam bentuk dataframe

data_pred['categori'] = model.predict(data_pred)
data_pred
# Out:
#    pm10  so2  co  o3  no2 categori
# 0    38   29   6  31   13   SEDANG
# 1    27   27   7  47    7     BAIK
# 2    44   25   7  40   13   SEDANG
# 3    30   24   4  32    7     BAIK
# 4    38   24   6  31    9     BAIK
# 5    41   23  13  46   13     BAIK
# 6    35   22   6  39   10     BAIK
# 7    37   26  16  17   10     BAIK
# 8    47   16  27  22   12     BAIK

# %% [markdown]
# **MENGGUNAKAN ALGORITMA RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline_model = Pipeline([
    ('preprocessor', pipeline_preprocessor),
    ('algoritma', RandomForestClassifier(n_jobs=-1, random_state=42))
])

# %%
parameter = {
    'algoritma__n_estimators': [100,150,200],                         # jumlah pohon(decision tree) yang digunakan
    'algoritma__max_depth': [20,50,80],                               # jumlah cabang yang digunakan
    'algoritma__max_features':[0.3,0.6,0.8],                          # jumlah feature yang akan dicek untuk setiap percabangan
    'algoritma__min_samples_leaf':[1,5,10]                            # jumlah leaf minimum disetiap cabang
    }

model =  GridSearchCV(pipeline_model, parameter,cv=3, n_jobs=-1, verbose=1)
model.fit(X_train,y_train)

# note: hasil model.fit --> 81 candidat (3 estimator x 3 max_depth x 3 max_feature x 3 min_samples_leaf = 81)
#                       --> 243 fits fits ( 81 candididat x 3 cv = 243)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['pm10',
#                                                                           'so2',
#                                                                           'co',
#                                                                           'o3',
#                                                                           'no2'])])),
#                                        ('algoritma',
#                                         RandomForestClassifier(n_jobs=-1,
#                                                                random_state=42))]),
#              n_jobs=-1,
#              param_grid={'algoritma__max_depth': [20, 50, 80],
#                          'algoritma__max_features': [0.3, 0.6, 0.8],
#                          'algoritma__min_samples_leaf': [1, 5, 10],
#                          'algoritma__n_estimators': [100, 150, 200]},
#              verbose=1)

# %%
model.best_params_
# Out:
# {'algoritma__max_depth': 20,
#  'algoritma__max_features': 0.6,
#  'algoritma__min_samples_leaf': 1,
#  'algoritma__n_estimators': 100}

# %%
print(f'Training score: {model.score(X_train,y_train)}')
print(f'Validation score: {model.best_score_}')
print(f'Testing sore: {model.score(X_test, y_test)}')
# Out:
# Training score: 1.0
# Validation score: 0.9856511919879565
# Testing sore: 0.9859484777517564

# %% [markdown]
# *Laporan lengkap hasil gridsearchCV berdasarkan rank test score*

# %%
report = pd.DataFrame(model.cv_results_).sort_values("rank_test_score")
report
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 36       0.569277      0.029221         0.053642        0.000854
# 63       0.914827      0.258996         0.073824        0.011406
# 9        1.423827      0.255942         0.109509        0.006533
# 19       1.784666      0.502025         0.109394        0.014528
# 46       0.879229      0.009042         0.071649        0.001732
# ..            ...           ...              ...             ...
# 62       0.829036      0.012968         0.097819        0.008235
# 35       0.889607      0.016056         0.106976        0.016403
# 33       0.423331      0.009053         0.055013        0.000888
# 6        0.420243      0.007441         0.059983        0.004753
# 60       0.413475      0.009484         0.054314        0.003102
#
#    param_algoritma__max_depth param_algoritma__max_features  \
# 36                         50                           0.6
# 63                         80                           0.6
# 9                          20                           0.6
# 19                         20                           0.8
# 46                         50                           0.8
# ..                        ...                           ...
# 62                         80                           0.3
# 35                         50                           0.3
# 33                         50                           0.3
# 6                          20                           0.3
# 60                         80                           0.3
#
#    param_algoritma__min_samples_leaf param_algoritma__n_estimators  \
# 36                                 1                           100
# 63                                 1                           100
# 9                                  1                           100
# 19                                 1                           150
# 46                                 1                           150
# ..                               ...                           ...
# 62                                10                           200
# 35                                10                           200
# 33                                10                           100
# 6                                 10                           100
# 60                                10                           100
#
#                                                params  split0_test_score  \
# 36  {'algoritma__max_depth': 50, 'algoritma__max_f...           0.986831
# 63  {'algoritma__max_depth': 80, 'algoritma__max_f...           0.986831
# 9   {'algoritma__max_depth': 20, 'algoritma__max_f...           0.986831
# 19  {'algoritma__max_depth': 20, 'algoritma__max_f...           0.985075
# 46  {'algoritma__max_depth': 50, 'algoritma__max_f...           0.985075
# ..                                                ...                ...
# 62  {'algoritma__max_depth': 80, 'algoritma__max_f...           0.970149
# 35  {'algoritma__max_depth': 50, 'algoritma__max_f...           0.970149
# 33  {'algoritma__max_depth': 50, 'algoritma__max_f...           0.967515
# 6   {'algoritma__max_depth': 20, 'algoritma__max_f...           0.967515
# 60  {'algoritma__max_depth': 80, 'algoritma__max_f...           0.967515
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 36           0.987698           0.982425         0.985651        0.002308
# 63           0.987698           0.982425         0.985651        0.002308
# 9            0.987698           0.982425         0.985651        0.002308
# 19           0.986819           0.984183         0.985359        0.001095
# 46           0.986819           0.984183         0.985359        0.001095
# ..                ...                ...              ...             ...
# 62           0.957821           0.949912         0.959294        0.008327
# 35           0.957821           0.949912         0.959294        0.008327
# 33           0.956063           0.951670         0.958416        0.006680
# 6            0.956063           0.951670         0.958416        0.006680
# 60           0.956063           0.951670         0.958416        0.006680
#
#     rank_test_score
# 36                1
# 63                1
# 9                 1
# 19                4
# 46                4
# ..              ...
# 62               76
# 35               76
# 33               79
# 6                79
# 60               79
#
# [81 rows x 15 columns]
